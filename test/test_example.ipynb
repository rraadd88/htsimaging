# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from htsimaging import ana_spt
expt_dh="../test_dataset/test_spt/ana/"
ana_spt.main(expt_dh)
# Out:
# Frame 115: 42 trajectories present
# PBS replicate 1
# filtered: 13 : 4
# filtered: 13 : 4
