# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from htsimaging import ana_spt
expt_dh="Munder2016/"
ana_spt.main(expt_dh)
# Out:
# Frame 120: 29 trajectories present
# GFPmuNS replicate 1
# 20.0
# filtered: 11 : 3
# filtered: 11 : 3
