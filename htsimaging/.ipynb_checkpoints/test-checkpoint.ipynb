# %%
import sys
import pandas as pd
import string
import numpy as np
from scipy import stats
import os
#from multiprocessing import Pool
from os.path import splitext,basename,exists
data_xls_fh='../test/test.xlsx'
info=pd.read_excel(data_xls_fh,'info')
info=info.set_index('varname')
for var in info.iterrows():
    val=info['input'][var[0]]
    #print var[0]
    if not pd.isnull(val):
        exec("%s=info['input']['%s']" % (var[0],var[0]))
    else:
        exec("%s=info['default']['%s']" % (var[0],var[0]))
data_job=pd.read_excel(data_xls_fh,'JobView')
data_job_del_cols=[str(s) for s in data_job.columns if 'Intensity' in str(s) ]
for col in data_job_del_cols:
    exec("del data_job['%s']" % col,locals(), globals())

nd_fns =[str(s) for s in data_job['File Name'].tolist()]
frameis=[int(s) for s in data_job['File Frame Index'].tolist()]

csv_fhs =[]
nums_fhs=[]
nd_fn_framei_tps=[]
for i in range(len(csv_fhs)):
    csv_fhs.append("%s/%s%02d.csv" % (nd_dh,nd_fns[i],frameis[i]))
    nums_fhs.append("%s/%s%02d.csv.nums" % (nd_dh,nd_fns[i],frameis[i]))
    nd_fn_framei_tps.append([nd_fns[i],frameis[i]])
data_job.head()
# Out:
#    Frame Index Frame Time  Task Name  File Frame Index  \
# 0            0   00:01:09  CaptureAB                 0
# 1            1   00:01:10  CaptureAB                 0
# 2            2   00:01:11  CaptureAB                 0
# 3            3   00:01:12  CaptureAB                 0
# 4            4   00:01:13  CaptureAB                 0
#
#                      File Name  Loop_bleach Index  TimeLapse1 Index  \
# 0  WellA01_WellA01_Seq0001.nd2                  0               NaN
# 1  WellA02_WellA02_Seq0002.nd2                  0               NaN
# 2  WellA03_WellA03_Seq0003.nd2                  0               NaN
# 3  WellA04_WellA04_Seq0004.nd2                  0               NaN
# 4  WellA05_WellA05_Seq0005.nd2                  0               NaN
#
#    loopAB Index  loopBC Index  loopCD Index    ...      loopHI Index  \
# 0             0           NaN           NaN    ...               NaN
# 1             1           NaN           NaN    ...               NaN
# 2             2           NaN           NaN    ...               NaN
# 3             3           NaN           NaN    ...               NaN
# 4             4           NaN           NaN    ...               NaN
#
#    loopIJ Index  loopJK Index  loopKL Index  loopLM Index  loopMN Index  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    loopNO Index  loopOP Index  loopP Index  Well Name
# 0           NaN           NaN          NaN        A01
# 1           NaN           NaN          NaN        A02
# 2           NaN           NaN          NaN        A03
# 3           NaN           NaN          NaN        A04
# 4           NaN           NaN          NaN        A05
#
# [5 rows x 24 columns]

# %%
data_job.head()
# Out:
#    Frame Index Frame Time  Task Name  File Frame Index  \
# 0            0   00:01:09  CaptureAB                 0
# 1            1   00:01:10  CaptureAB                 0
# 2            2   00:01:11  CaptureAB                 0
# 3            3   00:01:12  CaptureAB                 0
# 4            4   00:01:13  CaptureAB                 0
#
#                      File Name  Loop_bleach Index  TimeLapse1 Index  \
# 0  WellA01_WellA01_Seq0001.nd2                  0               NaN
# 1  WellA02_WellA02_Seq0002.nd2                  0               NaN
# 2  WellA03_WellA03_Seq0003.nd2                  0               NaN
# 3  WellA04_WellA04_Seq0004.nd2                  0               NaN
# 4  WellA05_WellA05_Seq0005.nd2                  0               NaN
#
#    loopAB Index  loopBC Index  loopCD Index    ...      loopHI Index  \
# 0             0           NaN           NaN    ...               NaN
# 1             1           NaN           NaN    ...               NaN
# 2             2           NaN           NaN    ...               NaN
# 3             3           NaN           NaN    ...               NaN
# 4             4           NaN           NaN    ...               NaN
#
#    loopIJ Index  loopJK Index  loopKL Index  loopLM Index  loopMN Index  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#    loopNO Index  loopOP Index  loopP Index  Well Name
# 0           NaN           NaN          NaN        A01
# 1           NaN           NaN          NaN        A02
# 2           NaN           NaN          NaN        A03
# 3           NaN           NaN          NaN        A04
# 4           NaN           NaN          NaN        A05
#
# [5 rows x 24 columns]

# %%
data_job.set_index(['File Name', 'File Frame Index'], inplace=True)

# %%
data_job.head()
# Out:
#                                               Frame Index Frame Time  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                           0   00:01:09
# WellA02_WellA02_Seq0002.nd2 0                           1   00:01:10
# WellA03_WellA03_Seq0003.nd2 0                           2   00:01:11
# WellA04_WellA04_Seq0004.nd2 0                           3   00:01:12
# WellA05_WellA05_Seq0005.nd2 0                           4   00:01:13
#
#                                               Task Name  Loop_bleach Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                 CaptureAB                  0
# WellA02_WellA02_Seq0002.nd2 0                 CaptureAB                  0
# WellA03_WellA03_Seq0003.nd2 0                 CaptureAB                  0
# WellA04_WellA04_Seq0004.nd2 0                 CaptureAB                  0
# WellA05_WellA05_Seq0005.nd2 0                 CaptureAB                  0
#
#                                               TimeLapse1 Index  loopAB Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                              NaN             0
# WellA02_WellA02_Seq0002.nd2 0                              NaN             1
# WellA03_WellA03_Seq0003.nd2 0                              NaN             2
# WellA04_WellA04_Seq0004.nd2 0                              NaN             3
# WellA05_WellA05_Seq0005.nd2 0                              NaN             4
#
#                                               loopBC Index  loopCD Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN           NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN           NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN           NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN           NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN           NaN
#
#                                               loopDE Index  loopEF Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN           NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN           NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN           NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN           NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN           NaN
#
#                                                 ...      loopHI Index  \
# File Name                   File Frame Index    ...
# WellA01_WellA01_Seq0001.nd2 0                   ...               NaN
# WellA02_WellA02_Seq0002.nd2 0                   ...               NaN
# WellA03_WellA03_Seq0003.nd2 0                   ...               NaN
# WellA04_WellA04_Seq0004.nd2 0                   ...               NaN
# WellA05_WellA05_Seq0005.nd2 0                   ...               NaN
#
#                                               loopIJ Index  loopJK Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN           NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN           NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN           NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN           NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN           NaN
#
#                                               loopKL Index  loopLM Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN           NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN           NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN           NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN           NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN           NaN
#
#                                               loopMN Index  loopNO Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN           NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN           NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN           NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN           NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN           NaN
#
#                                               loopOP Index  loopP Index  \
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                          NaN          NaN
# WellA02_WellA02_Seq0002.nd2 0                          NaN          NaN
# WellA03_WellA03_Seq0003.nd2 0                          NaN          NaN
# WellA04_WellA04_Seq0004.nd2 0                          NaN          NaN
# WellA05_WellA05_Seq0005.nd2 0                          NaN          NaN
#
#                                               Well Name
# File Name                   File Frame Index
# WellA01_WellA01_Seq0001.nd2 0                       A01
# WellA02_WellA02_Seq0002.nd2 0                       A02
# WellA03_WellA03_Seq0003.nd2 0                       A03
# WellA04_WellA04_Seq0004.nd2 0                       A04
# WellA05_WellA05_Seq0005.nd2 0                       A05
#
# [5 rows x 22 columns]

# %%
data_job.loc['WellA01_WellA01_Seq0001.nd2',0]['Task Name']
# Out:
# u'CaptureAB'

# %%
for i in range(len(nums_fhs)):        
    nd_fn=nd_fn_framei_tps[0]
    framei=nd_fn_framei_tps[1]
    data_job.loc[nd_fn,framei]['mean']
